# %%
import pandas as pd
import pandas_gbq
from helper import write_to_gcs

# Load data from sample_data.txt
with open('sample_data.txt', 'r') as f:
    sample_data = f.readlines()

# Create a DataFrame from the sample data
df = pd.DataFrame({'text_data': sample_data})

# Define your GCS bucket and file path
gcs_bucket = 'testing-depl'  # Replace with your GCS bucket name
gcs_file_path = 'output/sample_output.csv'

# Write the DataFrame to GCS using the helper function
write_to_gcs(df, gcs_bucket, gcs_file_path)

print(f"DataFrame successfully written to gs://{gcs_bucket}/{gcs_file_path}")
